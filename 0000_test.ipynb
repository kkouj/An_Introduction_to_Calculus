# %%
from sympy import *
import numpy as np

# %%
a,b,c, x, y, z, t = symbols('a b c x y z t')
k, m, n = symbols('k m n', integer=True)
f, g, h = symbols('f g h', cls=Function)
init_printing()

# %%
f = sin(x) / x

# %%
f
# Out:
# sin(x)
# ──────
#   x

# %%
diff(f,x,3)
# Out:
#           3⋅sin(x)   6⋅cos(x)   6⋅sin(x)
# -cos(x) + ──────── + ──────── - ────────
#              x           2          3
#                         x          x
# ────────────────────────────────────────
#                    x

# %%
series(f,x,0)
# Out:
#      2     4
#     x     x     ⎛ 6⎞
# 1 - ── + ─── + O⎝x ⎠
#     6    120

# %%
plot(f,(x,-10,10))
